# %%
#source: https://towardsdatascience.com/an-introduction-to-time-series-analysis-with-arima-a8b9c9a961fb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima
import pmdarima as pm
from datetime import datetime
from pmdarima.model_selection import train_test_split

# %%
df = pd.read_csv('passengers.csv', usecols=[1], engine='python')
plt.figure(figsize = (13,7))
plt.plot(df)

# %%
print(len(df))
# Out:
# 144

# %%
y = df.values
train, test = train_test_split(y, train_size=100)

# Fit model
model = pm.auto_arima(train, seasonal=True, m=12)

forecasts = model.predict(test.shape[0])

x = np.arange(y.shape[0])
plt.figure(figsize = (13,7))
plt.plot(x, y, c='blue' , label = 'expected')
plt.plot(x[100:], forecasts, c='green' , label = 'predicted')
plt.legend()
plt.show()
